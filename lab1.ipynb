# %% [markdown]
# ## <center>Computer Science Intensive Course - MindX</center>
# ![](./assets/logo.png)
# # <center>HOMEWORK 1. ÔN TẬP PYTHON</center>

# %% [markdown]
# ## Bài 1. Họ và Tên
# **Input**: cho người dùng nhập vào họ tên.
# **Output**: Họ và tên theo chuẩn tiếng Việt.
# **Ví dụ**:
# - Input:
#   + First name: Đông
#   + Middle name: Hà
#   + Last name: Nguyễn
# - Output: Nguyễn Hà Đông

# %%
first = input("Input first name: ")
middle = input("Input middle name: ")
last = input("Input last name: ")

print(f"{last} {middle} {first}")
# Out:
# Nguyễn Minh Hoàng

# %% [markdown]
# ## Bài 2. Số Lớn Thứ Hai
# **Input**: Cho người dùng nhập vào Số phần tử (n) họ mong muốn cho 1 danh sách, yêu cầu *n > 0* và *n* số nguyên, từ n phần tử đó hãy random ra danh sách có các phần tử trong phạm vi từ 1 đến 20. Tìm ra số lớn thứ hai.
# **Output**: Số lớn thứ hai trong các số đã nhập. In ra "Not found" nếu không tìm thấy.
# **Ví dụ**:
# Ví dụ 1:
# - Input: n = 4, arr = [5, 4, 1, 12]
# - Output: result = 5
# - Giải thích: Số lớn nhất là 12, số lớn thứ hai là 5
#
# Ví dụ 2:
# - Input: n = 4, arr = [5, 4, 1, 12, 5, 12]
# - Output: result = 5
# - Giải thích: Có hai số cùng lớn nhất là 12, hai số cùng lớn thứ hai là 5

# %%
import random
n = int(input("Nhập số phần tử: "))
arr = []
for i in range(n):
    num = random.randint(1,20)
    arr.append(num)
print(arr)
def delete_largest(list):
    for i in range(len(list)):
       max = i
       for j in range(i , len(list)):
           if list[j] > list[max]:
               max = j
       list[i], list[max] = list[max], list[i]
    max = list[0]
    print(max)
    while max in list:
        list.remove(max)
    return list
new_arr = delete_largest(arr)   
print(new_arr)  
print(f"Số lớn thứ 2 trong mảng là số {new_arr[0]}")
# Out:
# [12, 15, 2, 4, 16, 16, 10, 12, 9, 20]
# 20
# [16, 16, 15, 12, 12, 10, 9, 4, 2]
# Số lớn thứ 2 trong mảng [16, 16, 15, 12, 12, 10, 9, 4, 2] là số 16

# %% [markdown]
# ## Bài 3. Kiểm Tra Số Nguyên
# **Input**: Một số thực *a*.
# **Output**: Kiểm tra số thực *a* có phải là số nguyên hay không. In ra "Integer" hoặc "Not integer".
# **Ví dụ**:
# Ví dụ 1:
# - Input: a = 4
# - Output: "Integer"
#
# Ví dụ 2:
# - Input: a = 3.1416
# - Output: "Not integer"

# %%
a = input("Type a number: ")
if '.' in a:
    print('Not integer')
else:
    print('Integer')
# Out:
# Not integer
